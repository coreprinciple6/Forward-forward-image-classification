# %% [markdown]
# # Using the Forward-Forward Algorithm for Image Classification
#
# **Author:** [Suvaditya Mukherjee](https://twitter.com/halcyonrayes)<br>
# **Date created:** 2023/01/08<br>
# **Last modified:** 2023/01/08<br>
# **Description:** Training a Dense-layer model using the Forward-Forward algorithm.

# %% [markdown]
# ## Setup imports

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import random
from tensorflow.compiler.tf2xla.python import xla

# %% [markdown]
# ## Load the dataset and visualize the data
#
# We use the `keras.datasets.mnist.load_data()` utility to directly pull the MNIST dataset
# in the form of `NumPy` arrays. We then arrange it in the form of the train and test
# splits.
#
# Following loading the dataset, we select 4 random samples from within the training set
# and visualize them using `matplotlib.pyplot`.

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

print("4 Random Training samples and labels")
idx1, idx2, idx3, idx4 = random.sample(range(0, x_train.shape[0]), 4)

img1 = (x_train[idx1], y_train[idx1])
img2 = (x_train[idx2], y_train[idx2])
img3 = (x_train[idx3], y_train[idx3])
img4 = (x_train[idx4], y_train[idx4])

imgs = [img1, img2, img3, img4]

plt.figure(figsize=(10, 10))

for idx, item in enumerate(imgs):
    image, label = item[0], item[1]
    plt.subplot(2, 2, idx + 1)
    plt.imshow(image, cmap="gray")
    plt.title(f"Label : {label}")
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# 4 Random Training samples and labels

# %%
class FFDense(keras.layers.Layer):
    """
    A custom ForwardForward-enabled Dense layer. It has an implementation of the
    Forward-Forward network internally for use.
    This layer must be used in conjunction with the `FFNetwork` model.
    """

    def __init__(
        self,
        units,
        optimizer,
        loss_metric,
        num_epochs=70,
        use_bias=True,
        kernel_initializer="glorot_uniform",
        bias_initializer="zeros",
        kernel_regularizer=None,
        bias_regularizer=None,
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.dense = keras.layers.Dense(
            units=units,
            use_bias=use_bias,
            kernel_initializer=kernel_initializer,
            bias_initializer=bias_initializer,
            kernel_regularizer=kernel_regularizer,
            bias_regularizer=bias_regularizer,
        )
        self.relu = keras.layers.ReLU()
        self.optimizer = optimizer
        self.loss_metric = loss_metric
        self.threshold = 1.5
        self.num_epochs = num_epochs

    def call(self, x):
        x = tf.cast(x, dtype=tf.float32)
        x_norm = tf.norm(x, ord=2, axis=1, keepdims=True)
        x_norm = x_norm + 1e-4
        x_dir = x / x_norm
        res = self.dense(x_dir)
        return self.relu(res)

    def forward_forward(self, x_pos, x_neg):
        
        for i in range(self.num_epochs):
            with tf.GradientTape() as tape:
                g_pos = tf.math.reduce_mean(tf.math.pow(self.call(x_pos), 2), 1)
                g_neg = tf.math.reduce_mean(tf.math.pow(self.call(x_neg), 2), 1)

                margin_loss = tf.maximum(0., self.threshold - g_pos + g_neg)
                mean_margin_loss = tf.reduce_mean(margin_loss)

                self.loss_metric.update_state([mean_margin_loss])
            gradients = tape.gradient(mean_margin_loss, self.dense.trainable_weights)
            self.optimizer.apply_gradients(zip(gradients, self.dense.trainable_weights))

        return (
            tf.stop_gradient(self.call(x_pos)),
            tf.stop_gradient(self.call(x_neg)),
            self.loss_metric.result(),
        )

# %%
class FFNetwork(keras.Model):
    """
    A `keras.Model` that supports a `FFDense` network creation. This model
    can work for any kind of classification task. It has an internal
    implementation with some details specific to the MNIST dataset which can be
    changed as per the use-case.
    """

    def __init__(
        self,
        dims,
        layer_optimizer=keras.optimizers.legacy.Adam(learning_rate=0.09),
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.layer_optimizer = layer_optimizer
        self.loss_var = tf.Variable(0.0, trainable=False, dtype=tf.float32)
        self.loss_count = tf.Variable(0.0, trainable=False, dtype=tf.float32)
        self.layer_list = [keras.Input(shape=(dims[0],))]
        for d in range(2):
            self.layer_list += [
                FFDense(
                    300,
                    optimizer=self.layer_optimizer,
                    loss_metric=keras.metrics.Mean(),
                )
            ]


    @tf.function(reduce_retracing=True)
    def overlay_y_on_x(self, data):
        X_sample, y_sample = data

        max_sample = tf.reduce_max(X_sample, axis=0, keepdims=True)
        max_sample = tf.cast(max_sample, dtype=tf.float32)
        X_zeros = tf.zeros([10], dtype=tf.float32)
        X_update = xla.dynamic_update_slice(X_zeros, max_sample, [y_sample])
        X_sample = xla.dynamic_update_slice(X_sample, X_update, [0])
        return X_sample, y_sample

    @tf.function(reduce_retracing=True)
    def predict_one_sample(self, x):
        goodness_per_label = []
        x = tf.reshape(x, [tf.shape(x)[0] * tf.shape(x)[1]])
        for label in range(10):
            h, label = self.overlay_y_on_x(data=(x, label))
            h = tf.reshape(h, [-1, tf.shape(h)[0]])
            goodness = []
            for layer_idx in range(1, len(self.layer_list)):
                layer = self.layer_list[layer_idx]
                h = layer(h)
                goodness += [tf.math.reduce_mean(tf.math.pow(h, 2), 1)]
            goodness_per_label += [
                tf.expand_dims(tf.reduce_sum(goodness, keepdims=True), 1)
            ]
        goodness_per_label = tf.concat(goodness_per_label, 1)
        return tf.cast(tf.argmax(goodness_per_label, 1), tf.float32)

    def predict(self, data):
        x = data
        preds = list()
        preds = tf.map_fn(fn=self.predict_one_sample, elems=x)
        return np.asarray(preds, dtype=int)

    @tf.function(jit_compile=True)
    def train_step(self, data):
        x, y = data
        x = tf.cast(x, dtype=tf.float32)
        y = tf.cast(y, dtype=tf.int32)

        # Flatten op
        x = tf.reshape(x, [-1, tf.shape(x)[1] * tf.shape(x)[2]])

        x_pos, y = tf.map_fn(fn=self.overlay_y_on_x, elems=(x, y))
        
        random_y = tf.random.shuffle(y)
        x_neg, y = tf.map_fn(fn=self.overlay_y_on_x, elems=(x, random_y))
        x_neg = x_neg + tf.random.normal(shape=tf.shape(x_neg), mean=0.0, stddev=0.1)

        h_pos, h_neg = x_pos, x_neg

        for idx, layer in enumerate(self.layers):
            if isinstance(layer, FFDense):
                print(f"Training layer {idx+1} now : ")
                h_pos, h_neg, loss = layer.forward_forward(h_pos, h_neg)
                self.loss_var.assign_add(loss)
                self.loss_count.assign_add(1.0)
            else:
                print(f"Passing layer {idx+1} now : ")
                x = layer(x)
        mean_res = tf.math.divide(self.loss_var, self.loss_count)
        return {"FinalLoss": mean_res}

# %% [markdown]
# ## Convert MNIST `NumPy` arrays to `tf.data.Dataset`
#
# We now perform some preliminary processing on the `NumPy` arrays and then convert them
# into the `tf.data.Dataset` format which allows for optimized loading.

# %%
x_train = x_train.astype(float) / 255
x_test = x_test.astype(float) / 255
y_train = y_train.astype(int)
y_test = y_test.astype(int)

train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

train_dataset = train_dataset.batch(60000)
test_dataset = test_dataset.batch(10000)

# %% [markdown]
# ## Fit the network and visualize results
#
# Having performed all previous set-up, we are now going to run `model.fit()` and run 250
# model epochs, which will perform 50*250 epochs on each layer. We get to see the plotted loss
# curve as each layer is trained.

# %%
model = FFNetwork(dims=[784])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.09),
    loss="mse",
    jit_compile=True,
    metrics=[keras.metrics.Mean()],
)

epochs = 250
history = model.fit(train_dataset, epochs=epochs)
# Out:
# Epoch 1/250
# Training layer 1 now :
# Training layer 2 now :
# Training layer 1 now :
# Training layer 2 now :
# 1/1 [==============================] - 101s 101s/step - FinalLoss: 0.7549
# Epoch 2/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.6493
# Epoch 3/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.6001
# Epoch 4/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.5761
# Epoch 5/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.5437
# Epoch 6/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.5110
# Epoch 7/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.4851
# Epoch 8/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4629
# Epoch 9/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4403
# Epoch 10/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4246
# Epoch 11/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4079
# Epoch 12/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3925
# Epoch 13/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3793
# Epoch 14/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3670
# Epoch 15/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3563
# Epoch 16/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3463
# Epoch 17/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3383
# Epoch 18/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3304
# Epoch 19/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3233
# Epoch 20/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.3165
# Epoch 21/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3104
# Epoch 22/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3045
# Epoch 23/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2989
# Epoch 24/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2934
# Epoch 25/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2882
# Epoch 26/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2829
# Epoch 27/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2780
# Epoch 28/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2734
# Epoch 29/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2689
# Epoch 30/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2646
# Epoch 31/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2604
# Epoch 32/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2565
# Epoch 33/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2526
# Epoch 34/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2490
# Epoch 35/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2455
# Epoch 36/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2421
# Epoch 37/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2388
# Epoch 38/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2358
# Epoch 39/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2330
# Epoch 40/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2301
# Epoch 41/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2274
# Epoch 42/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2248
# Epoch 43/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2222
# Epoch 44/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2196
# Epoch 45/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2172
# Epoch 46/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2149
# Epoch 47/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2127
# Epoch 48/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2105
# Epoch 49/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2084
# Epoch 50/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2064
# Epoch 51/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2044
# Epoch 52/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2026
# Epoch 53/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.2007
# Epoch 54/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1989
# Epoch 55/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1971
# Epoch 56/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1954
# Epoch 57/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1937
# Epoch 58/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1921
# Epoch 59/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1905
# Epoch 60/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1889
# Epoch 61/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1873
# Epoch 62/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1857
# Epoch 63/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1843
# Epoch 64/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1828
# Epoch 65/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.1814
# Epoch 66/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1799
# Epoch 67/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.1785
# Epoch 68/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1771
# Epoch 69/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1758
# Epoch 70/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1745
# Epoch 71/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1733
# Epoch 72/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1720
# Epoch 73/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1708
# Epoch 74/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1696
# Epoch 75/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1684
# Epoch 76/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1673
# Epoch 77/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1661
# Epoch 78/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.1650
# Epoch 79/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.1639
# Epoch 80/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1628
# Epoch 81/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1617
# Epoch 82/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1606
# Epoch 83/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1596
# Epoch 84/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1586
# Epoch 85/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1575
# Epoch 86/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1565
# Epoch 87/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.1555
# Epoch 88/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1545
# Epoch 89/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1536
# Epoch 90/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1526
# Epoch 91/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1517
# Epoch 92/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1508
# Epoch 93/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1499
# Epoch 94/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1489
# Epoch 95/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1480
# Epoch 96/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1471
# Epoch 97/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.1461
# Epoch 98/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1452
# Epoch 99/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1443
# Epoch 100/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1434
# Epoch 101/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1425
# Epoch 102/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1416
# Epoch 103/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1407
# Epoch 104/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1398
# Epoch 105/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1390
# Epoch 106/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1381
# Epoch 107/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.1373
# Epoch 108/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1364
# Epoch 109/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1356
# Epoch 110/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1348
# Epoch 111/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1340
# Epoch 112/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1332
# Epoch 113/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1325
# Epoch 114/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1317
# Epoch 115/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1310
# Epoch 116/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1302
# Epoch 117/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1295
# Epoch 118/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1287
# Epoch 119/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1279
# Epoch 120/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1272
# Epoch 121/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1265
# Epoch 122/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1257
# Epoch 123/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1250
# Epoch 124/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1242
# Epoch 125/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1235
# Epoch 126/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1228
# Epoch 127/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1220
# Epoch 128/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1213
# Epoch 129/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1206
# Epoch 130/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1199
# Epoch 131/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1192
# Epoch 132/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1185
# Epoch 133/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1179
# Epoch 134/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.1172
# Epoch 135/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.1166
# Epoch 136/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.1159
# Epoch 137/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1153
# Epoch 138/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1146
# Epoch 139/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.1140
# Epoch 140/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1133
# Epoch 141/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1127
# Epoch 142/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1121
# Epoch 143/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1114
# Epoch 144/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1108
# Epoch 145/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1102
# Epoch 146/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1095
# Epoch 147/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1089
# Epoch 148/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1083
# Epoch 149/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1077
# Epoch 150/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1071
# Epoch 151/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1066
# Epoch 152/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1060
# Epoch 153/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1054
# Epoch 154/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1048
# Epoch 155/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1042
# Epoch 156/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1037
# Epoch 157/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1031
# Epoch 158/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1025
# Epoch 159/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1020
# Epoch 160/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1014
# Epoch 161/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1009
# Epoch 162/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.1003
# Epoch 163/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0998
# Epoch 164/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0992
# Epoch 165/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0987
# Epoch 166/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0981
# Epoch 167/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0976
# Epoch 168/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.0970
# Epoch 169/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0965
# Epoch 170/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0960
# Epoch 171/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0955
# Epoch 172/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0949
# Epoch 173/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0944
# Epoch 174/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0939
# Epoch 175/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0934
# Epoch 176/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0929
# Epoch 177/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0924
# Epoch 178/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0919
# Epoch 179/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0914
# Epoch 180/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.0909
# Epoch 181/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0905
# Epoch 182/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0900
# Epoch 183/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0895
# Epoch 184/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0891
# Epoch 185/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0886
# Epoch 186/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0882
# Epoch 187/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0877
# Epoch 188/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.0873
# Epoch 189/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0868
# Epoch 190/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0864
# Epoch 191/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0860
# Epoch 192/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.0856
# Epoch 193/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.0851
# Epoch 194/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0847
# Epoch 195/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0843
# Epoch 196/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0839
# Epoch 197/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0835
# Epoch 198/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0831
# Epoch 199/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0827
# Epoch 200/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0823
# Epoch 201/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0819
# Epoch 202/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0815
# Epoch 203/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.0811
# Epoch 204/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0807
# Epoch 205/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.0804
# Epoch 206/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.0800
# Epoch 207/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0796
# Epoch 208/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0792
# Epoch 209/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0789
# Epoch 210/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0785
# Epoch 211/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0781
# Epoch 212/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0778
# Epoch 213/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0774
# Epoch 214/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0771
# Epoch 215/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.0767
# Epoch 216/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0764
# Epoch 217/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0760
# Epoch 218/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0757
# Epoch 219/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0754
# Epoch 220/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0750
# Epoch 221/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0747
# Epoch 222/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0744
# Epoch 223/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0740
# Epoch 224/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0737
# Epoch 225/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.0734
# Epoch 226/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0731
# Epoch 227/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0728
# Epoch 228/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0725
# Epoch 229/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0721
# Epoch 230/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0718
# Epoch 231/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0715
# Epoch 232/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0712
# Epoch 233/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0709
# Epoch 234/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.0706
# Epoch 235/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.0703
# Epoch 236/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.0701
# Epoch 237/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0698
# Epoch 238/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0695
# Epoch 239/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0692
# Epoch 240/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0689
# Epoch 241/250
# 1/1 [==============================] - 5s 5s/step - FinalLoss: 0.0686
# Epoch 242/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0684
# Epoch 243/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0681
# Epoch 244/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0678
# Epoch 245/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0675
# Epoch 246/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0673
# Epoch 247/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0670
# Epoch 248/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0667
# Epoch 249/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0665
# Epoch 250/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.0662

# %% [markdown]
# ## Perform inference and testing
#
# Having trained the model to a large extent, we now see how it performs on the
# test set. We calculate the Accuracy Score to understand the results closely.

# %%
# import confusion matrix
from sklearn.metrics import confusion_matrix
x_test = tf.cast(x_test, dtype=tf.float32)

preds = model.predict(tf.convert_to_tensor(x_test))
preds = preds.reshape((preds.shape[0], preds.shape[1]))

results = accuracy_score(preds, y_test)
error_rate = 1 - results

cm = confusion_matrix(y_test, preds)
total = sum(sum(cm))
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])


print("The test confusion matrix is : ", cm)
print(f"Test Error rate : {error_rate*100}%")
print(f"Test Sensitivity : {sensitivity*100}%")
print(f"Test Specificity : {specificity*100}%")
f1 = 2 * (sensitivity * specificity) / (sensitivity + specificity)
print(f"Test F1 score : {f1*100}%")


plt.plot(range(len(history.history["FinalLoss"])), history.history["FinalLoss"])
plt.title("Loss over training")
plt.show()
# Out:
# int64
# The test confusion matrix is :  [[ 884    0    0    4    0   66   21    1    4    0]
#  [   0 1089    4    9    0    2    2    1   28    0]
#  [  25    4  874   40   23    6   20   11   29    0]
#  [   4   11   38  835    0   59    1   24   38    0]
#  [   0   10    2    3  865   14   28   49    7    4]
#  [   8    3    9  138   21  665    6    4   37    1]
#  [  20   14   19    1   11   47  840    2    4    0]
#  [   0   14   18    4   11    2    0  958   20    1]
#  [   2   13   26  130   10  139    4   28  621    1]
#  [   4   13    1   11  473   46    6  330   42   83]]
# Test Error rate : 22.860000000000003%
# Test Sensitivity : 100.0%
# Test Specificity : 100.0%
# Test F1 score : 100.0%
