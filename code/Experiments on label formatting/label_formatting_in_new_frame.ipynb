# %% [markdown]
# ## Setup imports

# %%
import tensorflow as tf
import os
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, accuracy_score
from sklearn.utils import shuffle
import random
from tensorflow.compiler.tf2xla.python import xla
#tf.compat.v1.enable_eager_execution()
#tf.config.run_functions_eagerly(True)

# %%
rand_seed = 42
tf.random.set_seed(rand_seed)
weights_base_path = ""
images_base_path = ""

# %% [markdown]
# ## Load the dataset and visualize the data
#
# We use the `keras.datasets.mnist.load_data()` utility to directly pull the MNIST dataset
# in the form of `NumPy` arrays. We then arrange it in the form of the train and test
# splits.
#
# Following loading the dataset, we select 4 random samples from within the training set
# and visualize them using `matplotlib.pyplot`.

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train, y_train = shuffle(x_train, y_train, random_state=rand_seed)
x_test, y_test = shuffle(x_test, y_test, random_state=rand_seed)

print("4 Random Training samples and labels")
idx1, idx2, idx3, idx4 = random.sample(range(0, x_train.shape[0]), 4)

img1 = (x_train[idx1], y_train[idx1])
img2 = (x_train[idx2], y_train[idx2])
img3 = (x_train[idx3], y_train[idx3])
img4 = (x_train[idx4], y_train[idx4])

imgs = [img1, img2, img3, img4]

plt.figure(figsize=(10, 10))

for idx, item in enumerate(imgs):
    image, label = item[0], item[1]
    plt.subplot(2, 2, idx + 1)
    plt.imshow(image, cmap="gray")
    plt.title(f"Label : {label}")
plt.show()

class_names = np.asarray([str(i) for i in range(10)])

true_labels = class_names[y_test]

# %% [markdown]
# ## Performance metrics and visualization

# %%
def plot_loss_curve(history, title, path_to_save=None):
    plt.plot(history.history["FinalLoss"], label="Training loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()
    if path_to_save:
        plt.savefig(path_to_save)


def load_eval_best_model(model, weights_path, test_images, true_labels, class_names, model_name):
    model.load_weights(weights_path)
    preds = model.predict(tf.convert_to_tensor(test_images))
    preds = preds.reshape((preds.shape[0], preds.shape[1]))
    pred_labels = class_names[np.argmax(preds, axis=1)]
   
    cm = confusion_matrix(true_labels, preds)

    disp = ConfusionMatrixDisplay(cm, display_labels=class_names)
    fig, ax = plt.subplots()
    fig.set_figheight(8)
    fig.set_figwidth(8)

    disp.plot(ax=ax, xticks_rotation='vertical', colorbar=False)
    plt.title("Confusion matrix of the " +
              model_name + " model on MNIST test set")
    plt.show()

    acc = accuracy_score(true_labels, preds)
    print(f"Test error rate: {1 - acc:.4f}")
    print(classification_report(true_labels, preds))

# %% [markdown]
# ## Define `FFDense` custom layer

# %%
class FFDense(keras.layers.Layer):
    """
    A custom ForwardForward-enabled Dense layer. It has an implementation of the
    Forward-Forward network internally for use.
    This layer must be used in conjunction with the `FFNetwork` model.
    """

    def __init__(
        self,
        units,
        optimizer,
        loss_metric,
        num_epochs=50,
        use_bias=True,
        kernel_initializer="glorot_uniform",
        bias_initializer="zeros",
        kernel_regularizer=None,
        bias_regularizer=None,
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.dense = keras.layers.Dense(
            units=units,
            use_bias=use_bias,
            kernel_initializer=kernel_initializer,
            bias_initializer=bias_initializer,
            kernel_regularizer=kernel_regularizer,
            bias_regularizer=bias_regularizer,
        )
        self.relu = keras.layers.ReLU()
        self.optimizer = optimizer
        self.loss_metric = loss_metric
        self.threshold = 1.5
        self.num_epochs = num_epochs


    def call(self, x):
        x_norm = tf.norm(x, ord=2, axis=1, keepdims=True)
        x_norm = x_norm + 1e-4
        x_dir = x / x_norm
        res = self.dense(x_dir)
        return self.relu(res)


    def forward_forward(self, x_pos, x_neg):
        for i in range(self.num_epochs):
            with tf.GradientTape() as tape:
                g_pos = tf.math.reduce_mean(tf.math.pow(self.call(x_pos), 2), 1)
                g_neg = tf.math.reduce_mean(tf.math.pow(self.call(x_neg), 2), 1)

                loss = tf.math.log(
                    1
                    + tf.math.exp(
                        tf.concat([-g_pos + self.threshold, g_neg - self.threshold], 0)
                    )
                )
                mean_loss = tf.cast(tf.math.reduce_mean(loss), tf.float32)
                self.loss_metric.update_state([mean_loss])
            gradients = tape.gradient(mean_loss, self.dense.trainable_weights)
            self.optimizer.apply_gradients(zip(gradients, self.dense.trainable_weights))
        return (
            tf.stop_gradient(self.call(x_pos)),
            tf.stop_gradient(self.call(x_neg)),
            self.loss_metric.result(),
        )

# %% [markdown]
# ## Define the `FFNetwork` Custom Model

# %%
class FFNetwork(keras.Model):
    """
    A `keras.Model` that supports a `FFDense` network creation. This model
    can work for any kind of classification task. It has an internal
    implementation with some details specific to the MNIST dataset which can be
    changed as per the use-case.
    """

    def __init__(
        self,
        dims,
        layer_optimizer=keras.optimizers.legacy.Adam(learning_rate=0.06),
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.layer_optimizer = layer_optimizer
        self.loss_var = tf.Variable(0.0, trainable=False, dtype=tf.float32)
        self.loss_count = tf.Variable(0.0, trainable=False, dtype=tf.float32)
        self.layer_list = [keras.Input(shape=(dims[0],))]
        for d in range(len(dims) - 1):
            self.layer_list += [
                FFDense(
                    dims[d + 1],
                    optimizer=self.layer_optimizer,
                    loss_metric=keras.metrics.Mean(),
                )
            ]

    @tf.function
    def add_one_hot_label(self, data):
        # Define some constants
        num_classes = 10
        input_height = 28
        input_width = 28

        # Unpack the input data into X_sample and y_sample
        X_sample, y_sample = data

        # Convert the label to one-hot encoded tensor
        label = tf.one_hot(y_sample, num_classes)

        # Create the label layer tensor with the one-hot encoded label
        label_layer = tf.tensor_scatter_nd_update(tf.zeros((input_height, input_width)), [[0, i] for i in range(num_classes)], label)

        # Cast the X_sample tensor to float32 and reshape it to the desired size
        X_sample_value = tf.cast(X_sample, dtype=tf.float32)
        X_sample_value = tf.reshape(X_sample_value, (input_height, input_width, 1))

        # Concatenate the label layer tensor with the X_sample tensor
        final_array = tf.concat([X_sample_value, tf.expand_dims(label_layer, -1)], -1)

        # Reshape the final image variable into a flattened tensor and cast it to float64
        new_X_sample = tf.cast(tf.reshape(final_array, (-1,)), tf.float64)

        # Return the new flattened image tensor and y_sample
        return new_X_sample, y_sample




    @tf.function(reduce_retracing=True)
    def predict_one_sample(self, x):
        goodness_per_label = []
        x = tf.reshape(x, [tf.shape(x)[0] * tf.shape(x)[1]])
        for label in range(10):
            h, label = self.add_one_hot_label(data=(x, label))
            h = tf.reshape(h, [-1, tf.shape(h)[0]])
            goodness = []
            for layer_idx in range(1, len(self.layer_list)):
                layer = self.layer_list[layer_idx]
                h = layer(h)
                goodness += [tf.math.reduce_mean(tf.math.pow(h, 2), 1)]
            goodness_per_label += [
                tf.expand_dims(tf.reduce_sum(goodness, keepdims=True), 1)
            ]
        goodness_per_label = tf.concat(goodness_per_label, 1)
        return tf.cast(tf.argmax(goodness_per_label, 1), tf.float64)

    def predict(self, data):
        x = data
        preds = list()
        preds = tf.map_fn(fn=self.predict_one_sample, elems=x)
        return np.asarray(preds, dtype=int)

    @tf.function(jit_compile=True)
    def train_step(self, data):
        x, y = data
        # Flatten op
        x = tf.reshape(x, [-1, tf.shape(x)[1] * tf.shape(x)[2]])
        #x = tf.cast(x,tf.float64)
        x_pos, y = tf.map_fn(fn=self.add_one_hot_label, elems=(x, y))

        random_y = tf.random.shuffle(y)
        x_neg, y = tf.map_fn(fn=self.add_one_hot_label, elems=(x, random_y))

        #h_pos, h_neg = x_pos, x_neg

        for idx, layer in enumerate(self.layers):
            if isinstance(layer, FFDense):
                print(f"Training layer {idx+1} now : ")
                x_pos, x_neg, loss = layer.forward_forward(x_pos, x_neg)
                self.loss_var.assign_add(loss)
                self.loss_count.assign_add(1.0)
            else:
                print(f"Passing layer {idx+1} now : ")
                x = layer(x)
        mean_res = tf.math.divide(self.loss_var, self.loss_count)
        return {"FinalLoss": mean_res}

# %% [markdown]
# ## Convert MNIST `NumPy` arrays to `tf.data.Dataset`
#
# We now perform some preliminary processing on the `NumPy` arrays and then convert them
# into the `tf.data.Dataset` format which allows for optimized loading.

# %%
x_train = x_train.astype(float) / 255
x_test = x_test.astype(float) / 255
y_train = y_train.astype(int)
y_test = y_test.astype(int)

train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

train_dataset = train_dataset.batch(60000)
test_dataset = test_dataset.batch(10000)

# %% [markdown]
# ## Fit the network and visualize results
#
# Having performed all previous set-up, we are now going to run `model.fit()` and run 250
# model epochs, which will perform 50*250 epochs on each layer. We get to see the plotted loss
# curve as each layer is trained.

# %%
model = FFNetwork(dims=[784, 500, 500])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.06),
    loss="mse",
    #jit_compile=True,
    metrics=[keras.metrics.Mean()]
)

epochs = 200
history = model.fit(train_dataset, epochs=epochs)
# Out:
# Epoch 1/200
# Training layer 1 now :
# Training layer 2 now :
# Training layer 1 now :
# Training layer 2 now :
# 1/1 [==============================] - 99s 99s/step - FinalLoss: 0.7170
# Epoch 2/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.6855
# Epoch 3/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.6630
# Epoch 4/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.6292
# Epoch 5/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.6001
# Epoch 6/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.5767
# Epoch 7/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.5575
# Epoch 8/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.5412
# Epoch 9/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.5274
# Epoch 10/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.5154
# Epoch 11/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.5048
# Epoch 12/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4954
# Epoch 13/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4869
# Epoch 14/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4793
# Epoch 15/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4722
# Epoch 16/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4658
# Epoch 17/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4598
# Epoch 18/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4544
# Epoch 19/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4493
# Epoch 20/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4446
# Epoch 21/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4402
# Epoch 22/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4362
# Epoch 23/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.4324
# Epoch 24/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4288
# Epoch 25/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4254
# Epoch 26/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4222
# Epoch 27/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4191
# Epoch 28/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4163
# Epoch 29/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4135
# Epoch 30/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4109
# Epoch 31/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4084
# Epoch 32/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4060
# Epoch 33/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4037
# Epoch 34/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.4016
# Epoch 35/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3994
# Epoch 36/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3974
# Epoch 37/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3955
# Epoch 38/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3936
# Epoch 39/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3918
# Epoch 40/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3901
# Epoch 41/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3884
# Epoch 42/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3868
# Epoch 43/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3852
# Epoch 44/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3837
# Epoch 45/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3822
# Epoch 46/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3807
# Epoch 47/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3793
# Epoch 48/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3779
# Epoch 49/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3766
# Epoch 50/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3753
# Epoch 51/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3740
# Epoch 52/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3728
# Epoch 53/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3717
# Epoch 54/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3705
# Epoch 55/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3694
# Epoch 56/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3682
# Epoch 57/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3672
# Epoch 58/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3661
# Epoch 59/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3650
# Epoch 60/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3640
# Epoch 61/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3631
# Epoch 62/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3621
# Epoch 63/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3612
# Epoch 64/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3603
# Epoch 65/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3593
# Epoch 66/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3585
# Epoch 67/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3576
# Epoch 68/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3568
# Epoch 69/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3559
# Epoch 70/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3551
# Epoch 71/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3544
# Epoch 72/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3536
# Epoch 73/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3529
# Epoch 74/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3521
# Epoch 75/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3514
# Epoch 76/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3507
# Epoch 77/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3500
# Epoch 78/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3493
# Epoch 79/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3486
# Epoch 80/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3479
# Epoch 81/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3472
# Epoch 82/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3465
# Epoch 83/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3459
# Epoch 84/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3452
# Epoch 85/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3446
# Epoch 86/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3440
# Epoch 87/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3434
# Epoch 88/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3428
# Epoch 89/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3422
# Epoch 90/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3417
# Epoch 91/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3411
# Epoch 92/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3406
# Epoch 93/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3400
# Epoch 94/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3395
# Epoch 95/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3390
# Epoch 96/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3385
# Epoch 97/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3380
# Epoch 98/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3375
# Epoch 99/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.3370
# Epoch 100/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3365
# Epoch 101/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3360
# Epoch 102/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3355
# Epoch 103/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3351
# Epoch 104/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3346
# Epoch 105/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3341
# Epoch 106/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3337
# Epoch 107/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3333
# Epoch 108/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3328
# Epoch 109/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.3324
# Epoch 110/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.3320
# Epoch 111/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3316
# Epoch 112/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3312
# Epoch 113/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3308
# Epoch 114/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3304
# Epoch 115/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3300
# Epoch 116/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.3296
# Epoch 117/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3292
# Epoch 118/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.3289
# Epoch 119/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3285
# Epoch 120/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3281
# Epoch 121/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3277
# Epoch 122/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3274
# Epoch 123/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3270
# Epoch 124/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.3267
# Epoch 125/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.3263
# Epoch 126/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3260
# Epoch 127/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3256
# Epoch 128/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3253
# Epoch 129/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.3250
# Epoch 130/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3247
# Epoch 131/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3243
# Epoch 132/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3240
# Epoch 133/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3237
# Epoch 134/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3234
# Epoch 135/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3231
# Epoch 136/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3228
# Epoch 137/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3225
# Epoch 138/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3222
# Epoch 139/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.3219
# Epoch 140/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3217
# Epoch 141/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3214
# Epoch 142/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3211
# Epoch 143/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3208
# Epoch 144/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3205
# Epoch 145/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3203
# Epoch 146/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3200
# Epoch 147/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3197
# Epoch 148/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3195
# Epoch 149/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3192
# Epoch 150/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.3189
# Epoch 151/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3187
# Epoch 152/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3184
# Epoch 153/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3181
# Epoch 154/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3179
# Epoch 155/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3176
# Epoch 156/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3174
# Epoch 157/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3171
# Epoch 158/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3169
# Epoch 159/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3167
# Epoch 160/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.3164
# Epoch 161/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3162
# Epoch 162/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3160
# Epoch 163/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3157
# Epoch 164/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3155
# Epoch 165/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3153
# Epoch 166/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3151
# Epoch 167/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3149
# Epoch 168/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3147
# Epoch 169/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3145
# Epoch 170/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3142
# Epoch 171/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3140
# Epoch 172/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3138
# Epoch 173/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3136
# Epoch 174/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3134
# Epoch 175/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3132
# Epoch 176/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3130
# Epoch 177/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.3128
# Epoch 178/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.3126
# Epoch 179/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3124
# Epoch 180/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3122
# Epoch 181/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3120
# Epoch 182/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3118
# Epoch 183/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3116
# Epoch 184/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3114
# Epoch 185/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3112
# Epoch 186/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3111
# Epoch 187/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3109
# Epoch 188/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3107
# Epoch 189/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3105
# Epoch 190/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3103
# Epoch 191/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3102
# Epoch 192/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3100
# Epoch 193/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3098
# Epoch 194/200
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.3097
# Epoch 195/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3095
# Epoch 196/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3093
# Epoch 197/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3092
# Epoch 198/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3090
# Epoch 199/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3088
# Epoch 200/200
# 1/1 [==============================] - 8s 8s/step - FinalLoss: 0.3087

# %%
# save the weights of the model
weights_path = os.path.join(weights_base_path, "4dims")
model.save_weights(weights_path)

# %% [markdown]
# ## Perform inference and testing
#
# Having trained the model to a large extent, we now see how it performs on the
# test set. We calculate the Accuracy Score to understand the results closely.

# %%
plot_path = os.path.join(images_base_path, "baseline-mnist.png")
plot_loss_curve(history,title="Baseline Model Loss Curve on MNIST Dataset")

model_name = "baseline_model"
load_eval_best_model(model, weights_path, x_test, y_test,class_names, model_name)
# Out:
# Test error rate: 0.0246
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.97      0.97      1032
#            3       0.97      0.97      0.97      1010
#            4       0.98      0.97      0.98       982
#            5       0.98      0.97      0.98       892
#            6       0.98      0.97      0.98       958
#            7       0.97      0.97      0.97      1028
#            8       0.95      0.98      0.96       974
#            9       0.98      0.97      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000
